# %% [markdown]
# ### Matplotlib

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot([1,2,3],[4,5,1])
plt.show()

# %%
x=[5,8,10]
y=[12,16,6]
X2=[6,9,11]
Y2=[6,15,7]
plt.plot(x,y,'blue',label='line one',linewidth=5)
plt.plot(X2,Y2,'black',label='line two',linewidth=5)
plt.title('info')
plt.ylabel('y axis')
plt.xlabel('x axis')
plt.legend()
# plt.grid(True, color='k')
plt.show()

# %%
from matplotlib import style

x=[5,8,10]
y=[12,16,6]
X2=[6,9,11]
Y2=[6,15,7]
plt.plot(x,y,'--r*')
plt.plot(X2,Y2,'--b+')
plt.title('info')
plt.ylabel('y axis')
plt.xlabel('x axis')
plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
import numpy as np

company=['AMZN','GOG','X','FB']
revenue = [90, 136, 89, 27]
xpos=np.arange(len(company))

profit=[40, 2, 34, 12]
plt.xticks(xpos,company)
plt.ylabel('revenue')
plt.title('US Tech Stocks')
plt.bar(xpos+0.2, revenue, color='b', width=0.4, label='Revenue')
plt.bar(xpos-0.2, profit, color='r', width=0.4, label='Profit')
plt.legend()
plt.show()

# %% [markdown]
# ### Pie Graph

# %%
plt.style.use('classic')
exp_vals=[1600,600,300,410,250]
exp_labels=['Home rent','Food','Phone/Internet Bill','Car','Other utilities']
plt.pie(exp_vals, labels=exp_labels, autopct='%0.2f%%', explode=[0,0.2,0,0,0])
plt.show()

# %%
import pandas as pd

# %%
data=pd.read_csv('C:/Users/PRANAV/Desktop/Python AIML 1/data.csv')

# %%
data
# Out:
#     Age  All_Devs  Python  JavaScript
# 0    18     17784   20046       16446
# 1    19     16500   17100       16791
# 2    20     18012   20000       18942
# 3    21     20628   24744       21780
# 4    22     25206   30500       25704
# 5    23     30252   37732       29000
# 6    24     34368   41247       34372
# 7    25     38496   45372       37810
# 8    26     42000   48876       43515
# 9    27     46752   53850       46823
# 10   28     49320   57287       49293
# 11   29     53200   63016       53437
# 12   30     56000   65998       56373
# 13   31     62316   70003       62375
# 14   32     64928   70000       66674
# 15   33     67317   71496       68745
# 16   34     68748   75370       68746
# 17   35     73752   83640       74583
# 18   36     77232   84666       79000
# 19   37     78000   84392       78508
# 20   38     78508   78254       79996
# 21   39     79536   85000       80403
# 22   40     82488   87038       83820
# 23   41     88935   91991       88833
# ...

# %%
data.isnull().sum()
# Out:
# Age           0
# All_Devs      0
# Python        0
# JavaScript    0
# dtype: int64

# %%
ages = data['Age']
dev_py = data['Python']
dev_js = data['JavaScript']
dev_other = data['All_Devs']

# %%
plt.plot(ages, dev_py, label='python dev')
plt.plot(ages, dev_js, label='javascript dev')
plt.plot(ages, dev_other, label='other dev', linestyle='--')
plt.title('Salaries info')
plt.legend()
plt.xlabel('Age')
plt.ylabel('Salary')

plt.show()

# %% [markdown]
# ### Histogram

# %%
blood_sugar = [113,85,90,150,149,88,93,115,135,80,77,82,129]
plt.hist(blood_sugar, bins=[75,100,125,150], rwidth=0.9)
plt.show()

# %%
med = data['Age'].median()
plt.hist(ages, bins=[10,20,30,40,50,60], edgecolor='black')

plt.axvline(med,linewidth=2, color='red')
plt.title('Age of developers')
plt.xlabel('Age of developer')
plt.ylabel('Count of developer')
plt.show()

# %% [markdown]
# ### Subplots

# %%
plt.figure(figsize=(6,3))
fig,(ax1,ax2) = plt.subplots(nrows=1, ncols=2, sharey=True)
ax1.plot(ages,dev_py, label='python dev')
ax1.legend()
ax1.set_xlabel('Age')
ax1.set_ylabel('Salary')
ax2.plot(ages, dev_js, label='javascript dev')
ax2.legend()

# %%
fifa = pd.read_csv('C:/Users/PRANAV/Desktop/Python AIML 1/fifa_data.csv')

# %%
fifa['Preferred Foot'].head()
# Out:
# 0     Left
# 1    Right
# 2    Right
# 3    Right
# 4    Right
# Name: Preferred Foot, dtype: object

# %%
fifa['Preferred Foot'].unique()
# Out:
# array(['Left', 'Right', nan], dtype=object)

# %%
g = fifa.groupby('Preferred Foot')

# %%
fifa.loc[fifa['Preferred Foot']=='Left','Preferred Foot'].count()
# Out:
# 4211

# %%
fifa.loc[fifa['Preferred Foot']=='Right','Preferred Foot'].count()
# Out:
# 13948

# %%
g['Preferred Foot'].count()
# Out:
# Preferred Foot
# Left      4211
# Right    13948
# Name: Preferred Foot, dtype: int64

# %%
plt.pie([4211,13948],autopct='%0.2f%%', labels=['Left','Right'])
plt.show()

# %%
# this method use to convert the str into int 
# this method is use to remove the str from the column

def convert(x):
    if type(x)==str:
        return x[:-3]
        x.str.replace('lbs','')
fifa['Weight1'] = fifa['Weight'].apply(convert)

# %%
fifa['Weight1'].head()
# Out:
# 0    159
# 1    183
# 2    150
# 3    168
# 4    154
# Name: Weight1, dtype: object

# %% [markdown]
# ### Seaborn

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill', y ='tip', hue='smoker', style='smoker', data=tips)

# %%
tips['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sns.relplot(x='total_bill', y='tip', row='day', col='time', data=tips)

# %%
sns.catplot(x='day', y='total_bill',kind='swarm',data=tips)

# %%
sns.countplot(x='time', data=tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='count'>

# %% [markdown]
# ### Heatmap

# %% [markdown]
# ### A heatmap is a graphical representation of data where values are expressed as colors. Heatmaps provide an effective visual summary of information because they synthesize data and then present it in a pictorial form

# %% [markdown]
# ### It allows for a large volume of data to be communicated almost instantly

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Correlation is used for measuring the strenght and direction of the linear relationship between two random variables x and y. It is statistical measure that indicates the extent to which two variables change together.

# %% [markdown]
# ### A positive correlation means the variable increase or decrease together. A negative correlation means if one variable increases, the other decreases. The correlation values can be computed using corr() method of dataframe and renderred using a heatmap

# %%
cr = iris.corr()
cr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(cr, annot=True)
# Out:
# <AxesSubplot:>
